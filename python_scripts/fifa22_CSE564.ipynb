# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
players = pd.read_csv("/content/players_fifa22.csv")
teams = pd.read_csv("/content/teams_fifa22.csv")

# %%
players
# Out:
#            ID               Name  ... RBRating  GKRating
# 0      158023           L. Messi  ...       64        22
# 1      188545     R. Lewandowski  ...       64        22
# 2       20801  Cristiano Ronaldo  ...       63        23
# 3      231747          K. Mbappé  ...       66        21
# 4      200389           J. Oblak  ...       35        92
# ...       ...                ...  ...      ...       ...
# 19255  262759           S. Black  ...       47        15
# 19256  250978            Ma Zhen  ...       26        49
# 19257  261985         Yang Haoyu  ...       48        15
# 19258  261977           He Siwei  ...       49        17
# 19259  261932      Chen Guoliang  ...       48        16
#
# [19260 rows x 90 columns]

# %%
players.isna().sum().to_dict()
# Out:
# {'Acceleration': 0,
#  'Age': 0,
#  'Aggression': 0,
#  'Agility': 0,
#  'AttackingWorkRate': 0,
#  'Balance': 0,
#  'BallControl': 0,
#  'BaseStats': 0,
#  'BestPosition': 0,
#  'CAMRating': 0,
#  'CBRating': 0,
#  'CDMRating': 0,
#  'CFRating': 0,
#  'CMRating': 0,
#  'Club': 0,
#  'ClubJoined': 0,
#  'ClubNumber': 76,
#  'ClubPosition': 76,
#  'Composure': 0,
#  'ContractUntil': 76,
#  'Crossing': 0,
#  'Curve': 0,
#  'DefendingTotal': 0,
#  'DefensiveWorkRate': 0,
#  'Dribbling': 0,
#  'DribblingTotal': 0,
#  'FKAccuracy': 0,
#  'Finishing': 0,
#  'FullName': 0,
#  'GKDiving': 0,
#  'GKHandling': 0,
#  'GKKicking': 0,
#  'GKPositioning': 0,
#  'GKRating': 0,
#  'GKReflexes': 0,
#  'Growth': 0,
#  'HeadingAccuracy': 0,
#  'Height': 0,
#  'ID': 0,
#  'IntReputation': 0,
#  'Interceptions': 0,
#  'Jumping': 0,
#  'LBRating': 0,
#  'LFRating': 0,
#  'LMRating': 0,
#  'LWBRating': 0,
#  'LWRating': 0,
#  'LongPassing': 0,
#  'LongShots': 0,
#  'Marking': 0,
#  'Name': 0,
# ...

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19260 entries, 0 to 19259
# Data columns (total 90 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 19260 non-null  int64
#  1   Name               19260 non-null  object
#  2   FullName           19260 non-null  object
#  3   Age                19260 non-null  int64
#  4   Height             19260 non-null  int64
#  5   Weight             19260 non-null  int64
#  6   PhotoUrl           19260 non-null  object
#  7   Nationality        19260 non-null  object
#  8   Overall            19260 non-null  int64
#  9   Potential          19260 non-null  int64
#  10  Growth             19260 non-null  int64
#  11  TotalStats         19260 non-null  int64
#  12  BaseStats          19260 non-null  int64
#  13  Positions          19260 non-null  object
#  14  BestPosition       19260 non-null  object
#  15  Club               19260 non-null  object
# ...

# %%
players.Nationality.unique()
# Out:
# array(['Argentina', 'Poland', 'Portugal', 'France', 'Slovenia', 'Belgium',
#        'Brazil', 'England', 'Germany', 'Korea Republic', 'Senegal',
#        'Netherlands', 'Italy', 'Egypt', 'Spain', 'Uruguay', 'Norway',
#        'Costa Rica', 'Croatia', 'Scotland', 'Slovakia', 'Algeria',
#        'Hungary', 'Switzerland', 'Denmark', 'Gabon', 'Morocco', 'Nigeria',
#        'Serbia', 'Austria', 'Sweden', 'Montenegro', "Côte d'Ivoire",
#        'Mexico', 'Greece', 'Bosnia and Herzegovina', 'Armenia', 'Finland',
#        'Cameroon', 'Colombia', 'Ghana', 'Canada', 'Czech Republic',
#        'United States', 'Jamaica', 'Turkey', 'Wales', 'Russia',
#        'Burkina Faso', 'Togo', 'Venezuela', 'Chile', 'Ukraine', 'Albania',
#        'Guinea', 'Northern Ireland', 'Israel', 'Congo DR', 'New Zealand',
#        'China PR', 'Peru', 'Central African Republic', 'Iceland', 'Mali',
#        'Japan', 'Iran', 'North Macedonia', 'Ecuador',
# ...

# %%
cols = ["Name", "Age", "Height",	"Weight","Overall",	"Potential",	"BestPosition",	"Club", "Nationality", "ValueEUR",	"WageEUR", "PreferredFoot", "SkillMoves" ,"PaceTotal", "ShootingTotal", "PassingTotal",	"DribblingTotal",	"DefendingTotal",	"Crossing", "Finishing" ,"Jumping", "Stamina", "Vision", "BallControl", "FKAccuracy", "Penalties"]

# %%
final_df = players[cols]

# %%
final_df
# Out:
#                     Name  Age  Height  ...  BallControl  FKAccuracy  Penalties
# 0               L. Messi   34     170  ...           96          94         75
# 1         R. Lewandowski   32     185  ...           88          85         90
# 2      Cristiano Ronaldo   36     187  ...           88          84         88
# 3              K. Mbappé   22     182  ...           91          69         79
# 4               J. Oblak   28     188  ...           30          14         11
# ...                  ...  ...     ...  ...          ...         ...        ...
# 19255           S. Black   19     180  ...           29          27         37
# 19256            Ma Zhen   23     196  ...           13          11          8
# 19257         Yang Haoyu   20     183  ...           26          24         37
# 19258           He Siwei   20     174  ...           29          22         38
# 19259      Chen Guoliang   22     186  ...           25          26         35
#
# ...

# %%
# b = final_df["NationalTeam"].value_counts().to_dict()
# import collections
# sorted_dict = collections.OrderedDict(b)
# sorted_dict

# final_df.NationalTeam.unique()

# %%
a = final_df["Nationality"].value_counts().to_dict()
import collections
sorted_dict = collections.OrderedDict(a)
sorted_dict
# Out:
# OrderedDict([('England', 1718),
#              ('Germany', 1214),
#              ('Spain', 1091),
#              ('France', 987),
#              ('Argentina', 955),
#              ('Brazil', 913),
#              ('Japan', 544),
#              ('Netherlands', 439),
#              ('United States', 411),
#              ('Poland', 403),
#              ('Sweden', 387),
#              ('Norway', 377),
#              ('Portugal', 377),
#              ('China PR', 377),
#              ('Republic of Ireland', 360),
#              ('Mexico', 355),
#              ('Saudi Arabia', 355),
#              ('Italy', 339),
#              ('Romania', 338),
#              ('Korea Republic', 323),
#              ('Colombia', 322),
#              ('Austria', 319),
#              ('Belgium', 313),
#              ('Denmark', 306),
#              ('Turkey', 292),
#              ('Scotland', 289),
#              ('Uruguay', 284),
#              ('Australia', 266),
#              ('India', 213),
# ...

# %%
# Top 21 countries as per fifa rankings
country = ["Belgium", "Brazil", "France", "England", "Argentina", "Italy", "Spain", "Portugal", "Denmark", "Netherlands", "United States", "Germany", "Switzerland", "Egypt", "Croatia", "Colombia", "Uruguay", "Sweden", "Senegal", "Mexico","Poland"]

# %%
national_cols =['Argentina', 'Poland', 'Portugal', 'France', 'Not in team',
       'Belgium', 'England', 'Germany', 'Netherlands', 'Italy', 'Spain',
       'Norway', 'Denmark', 'Sweden',
       'Mexico', 'Brazil', 'Canada',
       'United States', 'Wales', 'Greece', 'Ukraine', 'Northern Ireland',
       'New Zealand', 'China PR', 'Iceland', 'Russia',
       'Republic of Ireland', 'Romania', 'Australia']

# %%
final_df1 = final_df[final_df['Nationality'].isin(country)]
#final_df1 = final_df1[final_df1["NationalTeam"].isin(national_cols)]

# %%
final_df1
# Out:
#                     Name  Age  Height  ...  BallControl  FKAccuracy  Penalties
# 0               L. Messi   34     170  ...           96          94         75
# 1         R. Lewandowski   32     185  ...           88          85         90
# 2      Cristiano Ronaldo   36     187  ...           88          84         88
# 3              K. Mbappé   22     182  ...           91          69         79
# 5           K. De Bruyne   30     181  ...           91          83         83
# ...                  ...  ...     ...  ...          ...         ...        ...
# 19203          L. Haysen   19     183  ...           53          36         42
# 19212          B. Redžić   18     178  ...           51          30         52
# 19218           Bernardo   17     171  ...           45          39         47
# 19245  H. Wiles-Richards   19     180  ...           14          11         16
# 19254         F. Emmings   17     195  ...           14          13         15
#
# ...

# %%
final_df1 = final_df1[:710]

# %%
final_df1
# Out:
#                   Name  Age  Height  ...  BallControl  FKAccuracy  Penalties
# 0             L. Messi   34     170  ...           96          94         75
# 1       R. Lewandowski   32     185  ...           88          85         90
# 2    Cristiano Ronaldo   36     187  ...           88          84         88
# 3            K. Mbappé   22     182  ...           91          69         79
# 5         K. De Bruyne   30     181  ...           91          83         83
# ..                 ...  ...     ...  ...          ...         ...        ...
# 867   Gedson Fernandes   22     181  ...           78          70         60
# 868           A. Rossi   25     195  ...           26          21         23
# 869             Marcão   25     185  ...           72          34         56
# 870          E. Ndicka   21     192  ...           78          30         33
# 871             Soares   30     187  ...           77          40         75
#
# [710 rows x 26 columns]

# %%
final_df1.nunique()
# Out:
# Name              706
# Age                23
# Height             35
# Weight             42
# Overall            17
# Potential          18
# BestPosition       15
# Club              139
# Nationality        21
# ValueEUR          160
# WageEUR           117
# PreferredFoot       2
# SkillMoves          5
# PaceTotal          58
# ShootingTotal      69
# PassingTotal       45
# DribblingTotal     45
# DefendingTotal     70
# Crossing           81
# Finishing          90
# Jumping            62
# Stamina            70
# Vision             64
# BallControl        66
# FKAccuracy         82
# Penalties          82
# dtype: int64

# %%
final_df1.isna().sum()
# Out:
# Name              0
# Age               0
# Height            0
# Weight            0
# Overall           0
# Potential         0
# BestPosition      0
# Club              0
# Nationality       0
# ValueEUR          0
# WageEUR           0
# PreferredFoot     0
# SkillMoves        0
# PaceTotal         0
# ShootingTotal     0
# PassingTotal      0
# DribblingTotal    0
# DefendingTotal    0
# Crossing          0
# Finishing         0
# Jumping           0
# Stamina           0
# Vision            0
# BallControl       0
# FKAccuracy        0
# Penalties         0
# dtype: int64

# %%
final_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 710 entries, 0 to 871
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            710 non-null    object
#  1   Age             710 non-null    int64
#  2   Height          710 non-null    int64
#  3   Weight          710 non-null    int64
#  4   Overall         710 non-null    int64
#  5   Potential       710 non-null    int64
#  6   BestPosition    710 non-null    object
#  7   Club            710 non-null    object
#  8   Nationality     710 non-null    object
#  9   ValueEUR        710 non-null    int64
#  10  WageEUR         710 non-null    int64
#  11  PreferredFoot   710 non-null    object
#  12  SkillMoves      710 non-null    int64
#  13  PaceTotal       710 non-null    int64
#  14  ShootingTotal   710 non-null    int64
#  15  PassingTotal    710 non-null    int64
#  16  DribblingTotal  710 non-null    int64
# ...

# %%
final_df1.to_csv("processed_fifa22.csv",index=False)
